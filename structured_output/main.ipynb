# %%
import os
import json
from PyPDF2 import PdfReader

GROQ_API_KEY = os.getenv("GROQ_API_KEY")

from langchain_groq import ChatGroq

# %%
# Load the JSON schema from the file  
with open('./schema.json', 'r') as file:  
    schema = json.load(file)  

# Now you can use the schema variable  
schema
# Out:
# {'$schema': 'http://json-schema.org/draft-07/schema#',
#  'title': 'Candidate Information',
#  'type': 'object',
#  'required': ['personalInfo', 'roleInfo', 'resume'],
#  'properties': {'personalInfo': {'type': 'object',
#    'required': ['fullName', 'email', 'phone'],
#    'properties': {'fullName': {'type': 'string', 'minLength': 1},
#     'email': {'type': 'string', 'format': 'email'},
#     'phone': {'type': 'string', 'pattern': '^[+0-9\\-\\s]+$'},
#     'linkedin': {'type': 'string', 'format': 'uri', 'optional': True},
#     'github': {'type': 'string', 'format': 'uri', 'optional': True},
#     'portfolio': {'type': 'string', 'format': 'uri', 'optional': True}}},
#   'roleInfo': {'type': 'object',
#    'required': ['position', 'locationPreference'],
#    'properties': {'position': {'type': 'string', 'minLength': 1},
#     'locationPreference': {'type': 'string'},
#     'expectedSalary': {'type': 'number', 'optional': True},
#     'willingToRelocate': {'type': 'boolean', 'optional': True}}},
#   'education': {'type': 'array',
#    'items': {'type': 'object',
#     'required': ['degree', 'field', 'institution', 'graduationYear'],
#     'properties': {'degree': {'type': 'string'},
#      'field': {'type': 'string'},
#      'institution': {'type': 'string'},
#      'graduationYear': {'type': 'integer',
#       'minimum': 1900,
#       'maximum': 2100}}}},
#   'experience': {'type': 'array',
#    'items': {'type': 'object',
#     'required': ['company', 'title', 'startDate', 'endDate'],
#     'properties': {'company': {'type': 'string'},
#      'title': {'type': 'string'},
#      'startDate': {'type': 'string', 'format': 'date'},
#      'endDate': {'type': 'string', 'format': 'date'},
#      'achievements': {'type': 'string', 'optional': True}}}},
#   'skills': {'type': 'array', 'items': {'type': 'string'}},
#   'certifications': {'type': 'array',
#    'items': {'type': 'object',
#     'required': ['name', 'issuer', 'date'],
#     'properties': {'name': {'type': 'string'},
#      'issuer': {'type': 'string'},
#      'date': {'type': 'string', 'format': 'date'}}}},
#   'resume': {'type': 'string', 'contentEncoding': 'base64'},
#   'coverLetter': {'type': 'string', 'optional': True},
#   'references': {'type': 'array',
#    'items': {'type': 'object',
#     'required': ['name', 'contactInfo'],
#     'properties': {'name': {'type': 'string'},
#      'contactInfo': {'type': 'string'}}},
#    'optional': True},
#   'misc': {'type': 'object',
#    'required': ['availability', 'visaRequirements'],
#    'properties': {'availability': {'type': 'string'},
#     'visaRequirements': {'type': 'string'},
#     'comments': {'type': 'string', 'optional': True}}}}}

# %%
reader = PdfReader("./deedy-cv.pdf")
# print(reader.pages[0].extract_text())
text = ("\n").join([page.extract_text() for page in reader.pages])
text
# Out:
# 'Last Upda ted on 21st June 2019Debarghya Das\ndebargh y adas.c om | fb .c o/ dd\ndeed y @fb .c om | 60 7 .3 79.5733 | dd367@c ornell.edu\nEDUCATION\nCORNELL UNIVERSITY\nMENG IN COMPUTER SCIENCE\nDec 2014 | I thaca, NY\nCORNELL UNIVERSITY\nBS IN COMPUTER SCIENCE\nMa y 2014 | I thaca, NY\nCollege ofEngineering\nMagna Cum Laude\nC um. GP A: 3.83 / 4.0\nMajor GP A: 3.9 / 4.0\nLA MARTINIERE FOR BOYS\nGr ad. Ma y 2011| K olk a ta, India\nLINKS\nFacebook:// dd\nGithub:// deedydas\nLinkedIn:// debarghyadas\nYouTube:// DeedyDash007\nTwitter:// @debarghya_das\nQuora:// Debarghya-Das\nCOURSEWORK\nGRADUATE\nAdvanced Machine Learning\nOpen Source Software Engineering\nAdvanced Interactive Graphics\nCompilers +Practicum\nCloud Computing\nEvolutionary Computation\nDefending Computer Networks\nMachine Learning\nUNDERGRADUATE\nInformation Retrieval\nOperating Systems\nArtiﬁcial Intelligence +Practicum\nFunctional Programming\nComputer Graphics +Practicum\n(Research Asst. & T eaching Asst 2x)\nUnix Tools and Scripting\nSKILLS\nPROGRAMMING\nOver 5000 lines:\nJava •Shell •Python •Javascript\nOCaml •Matlab •Rails •LATEX\nOver 1000 lines:\nC•C++ •CSS •PHP •Assembly\nF amiliar:\nAS3 •iOS •Android •MySQLEXPERIENCE\nFACEBOOK | SOFTWARE ENGINEER\nJ an 2015 - Presen t | Ne w Y o rk , NY\nCOURSERA | KPCB FELLOW + SOFTWARE ENGINEERING INTERN\nJ une 2014 – Sep 2014 | Moun tain Vie w, C A\n•52out of2500 applicants chosen tobeaKPCB Fellow 2014.\n•Led and shipped Yoda -the admin interface for the new Phoenix platform.\n•Full-stack developer -Wrote and reviewed code for JSusing Backbone, Jade,\nStylus and Require and Scala using Play\nGOOGLE | SOFTWARE ENGINEERING INTERN\nMa y 2013 – A ug 2013 | Moun tain Vie w, C A\n•Worked onthe YouTube Captions team, inJavascript and Python toplan, to\ndesign and develop the full stack toadd and edit Automatic Speech Recognition\ncaptions. Inproduction.\n•Created abackbone.js-like framework for the Captions editor.\nPHABRICATOR | OPEN SOURCE CONTRIBUTO R & TEAM LEADER\nJ an 2013 – Ma y 2013 | P al o A l t o, C A & I thaca, NY\n•Phabricator isused daily byFacebook, Dropbox, Quora, Asana and more.\n•Icreated the Meme generator and more inPHP and Shell.\n•Led ateam from MIT, Cornell, ICLondon and UHelsinki for the project.\nRESEARCH\nCORNELL ROBOT LEARNING LAB | RESEARCHER\nJ an 2014 – J an 2015 | I thaca, NY\nWorked with Ashesh Jain and Prof Ashutosh Saxena tocreate PlanIt ,atool which\nlearns from large scale user preference feedback toplan robot trajectories inhuman\nenvironments.\nCORNELL PHONETICS LAB | H EAD UNDERGRADUATE RESEARCHER\nMar 2012 – Ma y 2013 | I thaca, NY\nLed the development ofQuickTongue ,the ﬁrst ever breakthrough tongue-controlled\ngame with Prof Sam Tilsen toaid inLinguistics research.\nAWARDS\n2014 top 52/2500 KPCB Engineering Fellow\n2014 1st/50 Microsoft Coding Competition, Cornell\n2013 National Jump Trading Challenge Finalist\n2013 7th/120 CS3410 Cache Race Bot Tournament\n2012 2nd/150 CS3110 Biannual Intra-Class Bot Tournament\n2011 National Indian National Mathematics Olympiad (INMO) Finalist\nPUBLICATIONS\n[1] A.Jain, D.Das, and A.Saxena. Planit: Acrowdsourcing approach for learning to\nplan paths from large scale preference feedback. T ech Report, ICRA ,inpress.\n[2] S.Tilsen, D.Das, and B.McKee. Real-time articulatory biofeedback with\nelectromagnetic articulography. Linguistics V anguard ,inpress.'

# %%
import pdfplumber

with pdfplumber.open("./deedy-cv.pdf") as pdf:
    text = "\n".join(page.extract_text() for page in pdf.pages)

# %%
text
# Out:
# 'LastUpdatedon21stJune2019\nDebarghya Das\ndebarghyadas.com|fb.co/dd\ndeedy@fb.com|607.379.5733|dd367@cornell.edu\nEDUCATION EXPERIENCE\nCORNELLUNIVERSITY FACEBOOK |SOFTWAREENGINEER\nMENGINCOMPUTERSCIENCE Jan2015-Present|NewYork,NY\nDec2014|Ithaca,NY\nCOURSERA |KPCBFELLOW+SOFTWAREENGINEERINGINTERN\nCORNELLUNIVERSITY June2014–Sep2014|MountainView,CA\nBSINCOMPUTERSCIENCE • 52outof2500applicantschosentobeaKPCBFellow2014.\nMay2014|Ithaca,NY • LedandshippedYoda-theadmininterfaceforthenewPhoenixplatform.\nCollegeofEngineering • Full-stackdeveloper-WroteandreviewedcodeforJSusingBackbone,Jade,\nMagnaCumLaude StylusandRequireandScalausingPlay\nCum. GPA:3.83/4.0\nMajorGPA:3.9/4.0 GOOGLE |SOFTWAREENGINEERINGINTERN\nMay2013–Aug2013|MountainView,CA\nLAMARTINIEREFORBOYS\n• WorkedontheYouTubeCaptionsteam,inJavascriptandPythontoplan,to\nGrad. May2011|Kolkata,India\ndesignanddevelopthefullstacktoaddandeditAutomaticSpeechRecognition\ncaptions.Inproduction.\nLINKS\n• Createdabackbone.js-likeframeworkfortheCaptionseditor.\nFacebook://dd\nPHABRICATOR |OPENSOURCECONTRIBUTOR&TEAMLEADER\nGithub://deedydas\nJan2013–May2013|PaloAlto,CA&Ithaca,NY\nLinkedIn://debarghyadas\n• PhabricatorisuseddailybyFacebook,Dropbox,Quora,Asanaandmore.\nYouTube://DeedyDash007\nTwitter://@debarghya_das • IcreatedtheMemegeneratorandmoreinPHPandShell.\nQuora://Debarghya-Das • LedateamfromMIT,Cornell,ICLondonandUHelsinkifortheproject.\nCOURSEWORK\nRESEARCH\nGRADUATE\nCORNELLROBOTLEARNINGLAB |RESEARCHER\nAdvancedMachineLearning\nJan2014–Jan2015|Ithaca,NY\nOpenSourceSoftwareEngineering\nWorkedwithAsheshJainandProfAshutoshSaxenatocreatePlanIt,atoolwhich\nAdvancedInteractiveGraphics\nlearnsfromlargescaleuserpreferencefeedbacktoplanrobottrajectoriesinhuman\nCompilers+Practicum\nenvironments.\nCloudComputing\nEvolutionaryComputation\nCORNELLPHONETICSLAB |HEADUNDERGRADUATERESEARCHER\nDefendingComputerNetworks\nMar2012–May2013|Ithaca,NY\nMachineLearning\nLedthedevelopmentofQuickTongue,thefirsteverbreakthroughtongue-controlled\nUNDERGRADUATE gamewithProfSamTilsentoaidinLinguisticsresearch.\nInformationRetrieval\nOperatingSystems AWARDS\nArtificialIntelligence+Practicum\nFunctionalProgramming 2014 top52/2500 KPCBEngineeringFellow\nComputerGraphics+Practicum 2014 1st/50 MicrosoftCodingCompetition,Cornell\n2013 National JumpTradingChallengeFinalist\n(ResearchAsst.&TeachingAsst2x)\nUnixToolsandScripting 2013 7th/120 CS3410CacheRaceBotTournament\n2012 2nd/150 CS3110BiannualIntra-ClassBotTournament\nSKILLS\n2011 National IndianNationalMathematicsOlympiad(INMO)Finalist\nPROGRAMMING\nPUBLICATIONS\nOver5000lines:\nJava•Shell•Python•Javascript [1] A.Jain,D.Das,andA.Saxena.Planit:Acrowdsourcingapproachforlearningto\nOCaml•Matlab•Rails•LATEX planpathsfromlargescalepreferencefeedback. TechReport,ICRA,inpress.\nOver1000lines:\nC•C++•CSS•PHP•Assembly [2] S.Tilsen,D.Das,andB.McKee. Real-timearticulatorybiofeedbackwith\nFamiliar: electromagneticarticulography.LinguisticsVanguard,inpress.\nAS3•iOS•Android•MySQL'

# %%
import pymupdf4llm
md_text = pymupdf4llm.to_markdown("./deedy-cv.pdf")
md_text
# Out:
# Processing ./deedy-cv.pdf...
# [                                        ] (0/1=======================================[========================================] (1/1]
# '# eba g ya as\n\n#### debarghyadas.com| fb.co/dd deedy@fb.com | 607.379.5733 | dd367@cornell.edu\n\n\n## EDUCATION\n### CORNELL UNIVERSITY\n#### MENG IN COMPUTER SCIENCE\nDec 2014 | Ithaca, NY\n\n### CORNELL UNIVERSITY\n#### BS IN COMPUTER SCIENCE\nMay 2014 | Ithaca, NY\nCollege of Engineering\nMagna Cum Laude\nCum. GPA: 3.83 / 4.0\nMajor GPA: 3.9 / 4.0\n\n### LA MARTINIERE FOR BOYS\nGrad. May 2011| Kolkata, India\n\n## LINKS\n\n[Facebook:// dd](https://facebook/dd)\n[Github:// deedydas](https://github.com/deedydas)\n[LinkedIn:// debarghyadas](https://www.linkedin.com/in/debarghyadas)\n[YouTube:// DeedyDash007](https://www.youtube.com/user/DeedyDash007)\n[Twitter:// @debarghya_das](https://twitter.com/debarghya_das)\n[Quora:// Debarghya-Das](https://www.quora.com/Debarghya-Das)\n\n## COURSEWORK\n### GRADUATE\nAdvanced Machine Learning\nOpen Source Software Engineering\nAdvanced Interactive Graphics\nCompilers + Practicum\nCloud Computing\nEvolutionary Computation\nDefending Computer Networks\nMachine Learning\n\n### UNDERGRADUATE\nInformation Retrieval\nOperating Systems\nArtificial Intelligence + Practicum\nFunctional Programming\nComputer Graphics + Practicum\n_(Research Asst. & Teaching Asst 2x)_\nUnix Tools and Scripting\n\n## SKILLS\n### PROGRAMMING\nOver 5000 lines:\nJava • Shell • Python • Javascript\nOCaml • Matlab • Rails • L[A]TEX\nOver 1000 lines:\nC • C++ • CSS • PHP • Assembly\nF ili\n\n\n## EXPERIENCE\n### FACEBOOK | SOFTWARE ENGINEER\nJan 2015 - Present | New York, NY\n\n### COURSERA | KPCB FELLOW + SOFTWARE ENGINEERING INTERN\nJune 2014 – Sep 2014 | Mountain View, CA\n\n  - 52 out of 2500 applicants chosen to be a KPCB Fellow 2014.\n\n  - Led and shipped Yoda - the admin interface for the new Phoenix platform.\n\n  - Full-stack developer - Wrote and reviewed code for JS using Backbone, Jade,\n\nStylus and Require and Scala using Play\n\n### GOOGLE | SOFTWARE ENGINEERING INTERN\nMay 2013 – Aug 2013 | Mountain View, CA\n\n  - Worked on the YouTube Captions team, in Javascript and Python to plan, to\n\ndesign and develop the full stack to add and edit Automatic Speech Recognition\ncaptions. In production.\n\n  - Created a backbone.js-like framework for the Captions editor.\n\n### PHABRICATOR | OPEN SOURCE CONTRIBUTOR & TEAM LEADER\nJan 2013 – May 2013 | Palo Alto, CA & Ithaca, NY\n\n  - Phabricator is used daily by Facebook, Dropbox, Quora, Asana and more.\n\n  - I created the Meme generator and more in PHP and Shell.\n\n  - Led a team from MIT, Cornell, IC London and UHelsinki for the project.\n\n## RESEARCH\n### CORNELL ROBOT LEARNING LAB | RESEARCHER\nJan 2014 – Jan 2015 | Ithaca, NY\n[Worked with Ashesh Jain and Prof Ashutosh Saxena to create PlanIt, a tool which](http://www.cs.cornell.edu/~ashesh/)\nlearns from large scale user preference feedback to plan robot trajectories in human\nenvironments.\n\n### CORNELL PHONETICS LAB | HEAD UNDERGRADUATE RESEARCHER\nMar 2012 – May 2013 | Ithaca, NY\nLed the development of QuickTongue, the first ever breakthrough tongue-controlled\n[game with Prof Sam Tilsen to aid in Linguistics research.](http://conf.ling.cornell.edu/~tilsen/)\n\n## AWARDS\n\n2014 top 52/2500 KPCB Engineering Fellow\n2014 1[st]/50 Microsoft Coding Competition, Cornell\n2013 National Jump Trading Challenge Finalist\n2013 7[th]/120 CS 3410 Cache Race Bot Tournament\n2012 2[nd]/150 CS 3110 Biannual Intra-Class Bot Tournament\n2011 National Indian National Mathematics Olympiad (INMO) Finalist\n\n## PUBLICATIONS\n\n[1] A. Jain, D. Das, and A. Saxena. Planit: A crowdsourcing approach for learning to\n\nplan paths from large scale preference feedback. Tech Report, ICRA, in press.\n\n[2] S. Tilsen, D. Das, and B. McKee. Real-time articulatory biofeedback with\n\nelectromagnetic articulography Linguistics Vanguard in press\n\n\n-----\n\n'

# %%
llm = ChatGroq(model="llama-3.3-70b-specdec")

structured_llm = llm.with_structured_output(schema)

parsed = structured_llm.invoke(f"Extract the following information with as much detail as possible. Ensure all items, including multiple companies and achievements, are parsed: {text}")

print(parsed)
# Out:
# {'personalInfo': {'fullName': 'Debarghya Das', 'email': 'dd367@cornell.edu', 'phone': '607.379.5733', 'github': 'https://github.com/deedydas', 'linkedin': 'https://www.linkedin.com/in/debarghyadas', 'portfolio': 'https://debarghyadas.com'}, 'roleInfo': {'position': 'Software Engineer', 'locationPreference': 'New York, NY', 'expectedSalary': None, 'willingToRelocate': None}, 'education': [{'degree': 'BS in Computer Science', 'field': 'Computer Science', 'graduationYear': 2015, 'institution': 'Cornell University'}], 'experience': [{'company': 'Facebook', 'title': 'Software Engineer', 'startDate': '2015-01-01', 'endDate': 'Present', 'achievements': 'Led and shipped Yoda - the admin interface for the new Phoenix platform. Full-stack developer - Wrote and reviewed code for JS using Backbone, Jade, Stylus and Require and Scala using Play'}, {'company': 'Coursera', 'title': 'KPCB Fellow + Software Engineering Intern', 'startDate': '2014-06-01', 'endDate': '2014-09-01', 'achievements': 'One of 52 out of 2500 applicants chosen to be a KPCB Fellow 2014'}, {'company': 'Google', 'title': 'Software Engineering Intern', 'startDate': '2013-05-01', 'endDate': '2013-08-01', 'achievements': 'Worked on the YouTube Caption team, in Javascript and Python, to design and develop the full stack to add and edit Automatic Speech Recognition captions. Created a backbone.js-like framework for the Captions editor'}, {'company': 'Phabricator', 'title': 'Open Source Contributor & Team Leader', 'startDate': '2013-01-01', 'endDate': '2013-05-01', 'achievements': 'Phabricator is used daily by Facebook, Dropbox, Quora, Asana and more. Created the Memegenerator and more in PHP and Shell. Led a team from MIT, Cornell, IC London and UHelsinki for the project'}], 'skills': ['Java', 'Shell', 'Python', 'Javascript', 'OCaml', 'Matlab', 'Rails', 'LATEX', 'C', 'C++', 'CSS', 'PHP', 'Assembly', 'AS3', 'iOS', 'Android', 'MySQL'], 'certifications': [], 'misc': {'availability': None, 'visaRequirements': None, 'comments': None}, 'references': [], 'resume': None, 'coverLetter': None}

# %%
# Convert the data to JSON format  
json_data = json.dumps(parsed, indent=4)  

# Print the JSON string  
print(json_data)
# Out:
# {
#     "personalInfo": {
#         "fullName": "Debarghya Das",
#         "email": "dd367@cornell.edu",
#         "phone": "607.379.5733",
#         "github": "https://github.com/deedydas",
#         "linkedin": "https://www.linkedin.com/in/debarghyadas",
#         "portfolio": "https://debarghyadas.com"
#     },
#     "roleInfo": {
#         "position": "Software Engineer",
#         "locationPreference": "New York, NY",
#         "expectedSalary": null,
#         "willingToRelocate": null
#     },
#     "education": [
#         {
#             "degree": "BS in Computer Science",
#             "field": "Computer Science",
#             "graduationYear": 2015,
#             "institution": "Cornell University"
#         }
#     ],
#     "experience": [
#         {
#             "company": "Facebook",
#             "title": "Software Engineer",
#             "startDate": "2015-01-01",
#             "endDate": "Present",
#             "achievements": "Led and shipped Yoda - the admin interface for the new Phoenix platform. Full-stack developer - Wrote and reviewed code for JS using Backbone, Jade, Stylus and Require and Scala using Play"
#         },
#         {
#             "company": "Coursera",
#             "title": "KPCB Fellow + Software Engineering Intern",
#             "startDate": "2014-06-01",
#             "endDate": "2014-09-01",
#             "achievements": "One of 52 out of 2500 applicants chosen to be a KPCB Fellow 2014"
#         },
#         {
#             "company": "Google",
#             "title": "Software Engineering Intern",
#             "startDate": "2013-05-01",
#             "endDate": "2013-08-01",
#             "achievements": "Worked on the YouTube Caption team, in Javascript and Python, to design and develop the full stack to add and edit Automatic Speech Recognition captions. Created a backbone.js-like framework for the Captions editor"
#         },
#         {
#             "company": "Phabricator",
#             "title": "Open Source Contributor & Team Leader",
#             "startDate": "2013-01-01",
#             "endDate": "2013-05-01",
#             "achievements": "Phabricator is used daily by Facebook, Dropbox, Quora, Asana and more. Created the Memegenerator and more in PHP and Shell. Led a team from MIT, Cornell, IC London and UHelsinki for the project"
#         }
#     ],
#     "skills": [
#         "Java",
#         "Shell",
#         "Python",
#         "Javascript",
#         "OCaml",
#         "Matlab",
#         "Rails",
#         "LATEX",
#         "C",
#         "C++",
#         "CSS",
#         "PHP",
#         "Assembly",
#         "AS3",
#         "iOS",
#         "Android",
#         "MySQL"
#     ],
#     "certifications": [],
#     "misc": {
#         "availability": null,
#         "visaRequirements": null,
#         "comments": null
#     },
#     "references": [],
#     "resume": null,
#     "coverLetter": null
# }

# %%
from unstructured.partition.auto import partition

elements = partition(filename="./deedy-cv.pdf")
print("\n\n".join([str(el) for el in elements]))
# Out:
# EDUCATION CORNELL UNIVERSITY MENG IN COMPUTER SCIENCE Dec 2014 | Ithaca, NY
#
# CORNELL UNIVERSITY BS IN COMPUTER SCIENCE May 2014 | Ithaca, NY College of Engineering Magna Cum Laude Cum. GPA: 3.83 / 4.0 Major GPA: 3.9 / 4.0
#
# LA MARTINIERE FOR BOYS Grad. May 2011| Kolkata, India
#
# LINKS Facebook:// dd Github:// deedydas LinkedIn:// debarghyadas YouTube:// DeedyDash007 Twitter:// @debarghya_das Quora:// Debarghya-Das
#
# COURSEWORK GRADUATE Advanced Machine Learning Open Source Software Engineering Advanced Interactive Graphics Compilers + Practicum Cloud Computing Evolutionary Computation Defending Computer Networks Machine Learning
#
# UNDERGRADUATE Information Retrieval Operating Systems Artiﬁcial Intelligence + Practicum Functional Programming Computer Graphics + Practicum (Research Asst. & Teaching Asst 2x) Unix Tools and Scripting
#
# SKILLS PROGRAMMING Over 5000 lines: Java • Shell • Python • Javascript OCaml • Matlab • Rails • LATEX Over 1000 lines: C • C++ • CSS • PHP • Assembly Familiar: AS3 • iOS • Android • MySQL
#
# Debarghya Das
#
# Last Updated on 21st June 2019
#
# debarghyadas.com| fb.co/dd deedy@fb.com | 607.379.5733 | dd367@cornell.edu
#
# EXPERIENCE FACEBOOK | SOFTWARE ENGINEER Jan 2015 - Present | New York, NY
#
# COURSERA | KPCB FELLOW + SOFTWARE ENGINEERING INTERN June 2014 – Sep 2014 | Mountain View, CA
#
# 52 out of 2500 applicants chosen to be a KPCB Fellow 2014. • Led and shipped Yoda - the admin interface for the new Phoenix platform. • Full-stack developer - Wrote and reviewed code for JS using Backbone, Jade, Stylus and Require and Scala using Play
#
# GOOGLE | SOFTWARE ENGINEERING INTERN May 2013 – Aug 2013 | Mountain View, CA
#
# Worked on the YouTube Captions team, in Javascript and Python to plan, to design and develop the full stack to add and edit Automatic Speech Recognition captions. In production.
#
# Created a backbone.js-like framework for the Captions editor.
#
# PHABRICATOR | OPEN SOURCE CONTRIBUTOR & TEAM LEADER Jan 2013 – May 2013 | Palo Alto, CA & Ithaca, NY
#
# Phabricator is used daily by Facebook, Dropbox, Quora, Asana and more. • I created the Meme generator and more in PHP and Shell. • Led a team from MIT, Cornell, IC London and UHelsinki for the project.
#
# RESEARCH CORNELL ROBOT LEARNING LAB | RESEARCHER Jan 2014 – Jan 2015 | Ithaca, NY Worked with Ashesh Jain and Prof Ashutosh Saxena to create PlanIt, a tool which learns from large scale user preference feedback to plan robot trajectories in human environments.
#
# CORNELL PHONETICS LAB | HEAD UNDERGRADUATE RESEARCHER Mar 2012 – May 2013 | Ithaca, NY Led the development of QuickTongue, the ﬁrst ever breakthrough tongue-controlled game with Prof Sam Tilsen to aid in Linguistics research.
#
# AWARDS 2014 2014 2013 National 7th/120 2013 2nd/150 2012 2011 National
#
# top 52/2500 KPCB Engineering Fellow 1st/50
#
# Microsoft Coding Competition, Cornell Jump Trading Challenge Finalist CS 3410 Cache Race Bot Tournament CS 3110 Biannual Intra-Class Bot Tournament Indian National Mathematics Olympiad (INMO) Finalist
#
# PUBLICATIONS [1] A. Jain, D. Das, and A. Saxena. Planit: A crowdsourcing approach for learning to plan paths from large scale preference feedback. Tech Report, ICRA, in press.
#
# [2] S. Tilsen, D. Das, and B. McKee. Real-time articulatory biofeedback with
#
# electromagnetic articulography. Linguistics Vanguard, in press.

# %%
from markitdown import MarkItDown

md = MarkItDown()

# %%
result = md.convert("./deedy-cv.pdf")
print(result.text_content)

# %%
result = md.convert("./resume-template_table.docx")
print(result.text_content)
# Out:
# Your Name
#
# 100 Tree River Lane, Anytown, CA 12345 • 111-222-3333 • name@gmail.com
#
# This [Resume Template](https://www.vertex42.com/resumes/free-resume-template.html) provides an example of how to use a table format to present your resume with major section headings on the left hand side. Modify the section headings and content as needed. To add a tab when you are working in a table, you can press Ctrl+tab. To show/hide the table gridlines while you are working, go to: Table > Hide/Show Gridlines. Modify the Normal style to change the font for the entire page and modify Heading 1 to change the section heading style. This template is copyrighted by Vertex42.com (see [terms of use](https://www.vertex42.com/licensing/EULA_privateuse.html)). Visit vertex42.com for more information and [resume tips](https://www.vertex42.com/resumes/resume-tips.html).
#
# | Objective | A [type or title of position] position in the [name of industry] industry where my expertise in [area 1] and [area 2] would be needed | |
# | --- | --- | --- |
# | Summary of Qualifications | Senior Level Technical Manager with 15 years of management experience, a Masters degree in Mechanical Engineering, and 10 years as design engineer in the auto industry.   * Consider listing qualifications using bullets * Especially skilled at [skill1], [skill2], [skill 3]… * Proven ability to … A talent for … Skilled in … Extensive knowledge of … * Expertise in [skill 1, skill 2, skill 3] | |
# | Experience | **Company Name**, Location 2005 to Present  **Position**   * Taught … * Supervised … * Increased sales by …   **Company/Organization**, Location 2003 to 2005  **Position**   * Organized … * Developed …   **Company/Organization**, Location 2000 to 2003  **Position**   * Prepared … * Conducted … | |
# | Education | **M.S. Electrical Engineering**, University Name, Location May 2000  Thesis: “Title”, Advisor: Name  **B.S. Electrical Engineering**, University Name, Location May 1998  Minored in Mathematics  Major GPA: 3.6/4.0 Overall GPA: 3.2/4.0 | |
# | Computer Skills | * Java, Visual Basic, C++, PHP * MS Excel, Word, PowerPoint * MS Access, MySQL, Oracle | * AutoCAD, SolidWorks * MATLAB, Mathematica * Windows, Linux, Mac OS |
# | Languages | English: Native language  **Spanish**: Intermediate Listener, Novice Speaker, Advanced Reading and Writing | |
# | Activities and Interests | Scoutmaster (Eagle Scout), Amateur radio (N7ABC), Gardening, Mountain biking, Carpentry, Computers, Cycling, Hiking | |
# | References | Available upon request | |

# %%
result = md.convert("./resume-template_table.pdf")
print(result.text_content)
# Out:
# YOUR NAME
# 100 Tree River Lane, Anytown, CA 12345 • 111-222-3333 • name@gmail.com
#
# This Resume Template provides an example of how to use a table format to present your resume with
# major section headings on the left hand side. Modify the section headings and content as needed. To add
# a tab when you are working in a table, you can press Ctrl+tab. To show/hide the table gridlines while you
# are working, go to: Table > Hide/Show Gridlines. Modify the Normal style to change the font for the entire
# page and modify Heading 1 to change the section heading style. This template is copyrighted by
# Vertex42.com (see terms of use). Visit vertex42.com for more information and resume tips.
#
# OBJECTIVE
#
# A [type or title of position] position in the [name of industry] industry where my
# expertise in [area 1] and [area 2] would be needed
#
# SUMMARY OF
# QUALIFICATIONS
#
# Senior Level Technical Manager with 15 years of management experience, a
# Masters degree in Mechanical Engineering, and 10 years as design engineer in
# the auto industry.
#  Consider listing qualifications using bullets
# 
# 
# 
#
# Especially skilled at [skill1], [skill2], [skill 3]…
# Proven ability to … A talent for … Skilled in … Extensive knowledge of …
# Expertise in [skill 1, skill 2, skill 3]
#
# EXPERIENCE
#
# Company Name, Location
# Position
# 
# 
# 
#
# Taught …
# Supervised …
# Increased sales by …
#
# Company/Organization, Location
# Position
#  Organized …
#  Developed …
#
# Company/Organization, Location
# Position
# 
#  Conducted …
#
# Prepared …
#
# 2005 to Present
#
# 2003 to 2005
#
# 2000 to 2003
#
# EDUCATION
#
# M.S. Electrical Engineering, University Name, Location
#
# May 2000
#
# Thesis: “Title”, Advisor: Name
#
# B.S. Electrical Engineering, University Name, Location
#
# May 1998
#
# Minored in Mathematics
# Major GPA: 3.6/4.0 Overall GPA: 3.2/4.0
#
# COMPUTER
# SKILLS
#
# Java, Visual Basic, C++, PHP
# 
#  MS Excel, Word, PowerPoint
#  MS Access, MySQL, Oracle
#
# AutoCAD, SolidWorks
#
# 
#  MATLAB, Mathematica
#  Windows, Linux, Mac OS
#
# LANGUAGES
#
# English: Native language
# Spanish: Intermediate Listener, Novice Speaker, Advanced Reading and Writing
#
# ACTIVITIES AND
# INTERESTS
#
# Scoutmaster (Eagle Scout), Amateur radio (N7ABC), Gardening, Mountain
# biking, Carpentry, Computers, Cycling, Hiking
#
# REFERENCES
#
# Available upon request

# %%
['convert',
 'convert_local',
 'convert_response',
 'convert_stream',
 'convert_url',
 'register_page_converter']

# %%
text = md.convert_url("https://dev-kol.trackerai.bot")
print(text.text_content)
# Out:
# You need to enable JavaScript to run this app.

# %%
text = md.convert("./Tracker.html")
print(text.text_content)
# Out:
# You need to enable JavaScript to run this app.![logo](./Tracker_files/logo.png)
#
# * Home
# * Recent Calls
# * Follow up Calls
# * Token Stats
# Pricing Page![questionMark](./Tracker_files/questionMark.png)![Notification-img](./Tracker_files/Notification.png)Login With TelegramLogin![logo](./Tracker_files/logo.png)![ethereum-img](./Tracker_files/ethereum.png)
#
# ETHEREUM
#
# #1
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #2
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #3
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #4
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #5
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #6
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #7
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #8
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #9
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #10
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #1
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #2
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #3
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #4
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #5
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #6
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #7
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #8
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #9
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# #10
#
# ![ETH](./Tracker_files/60989b438a473ed77703f7bcd3530fc15542996a6607ae831de8c5e3e10f688d.png)
#
# $ETH
#
# 0.0011941531
#
# ![star img](./Tracker_files/star.png)
#
# You can display your ad here
#
# ![star img](./Tracker_files/star.png)
#
# TrackerAI\_ERC just made a call for $ETH and has generated over$5530271.100000001in buys
#
# ![stars](./Tracker_files/satrs-stretch.png)
# #### Top 3 influencers
#
# ![profile](./Tracker_files/S3-NhpCA_normal.jpg)
# ###### ZssBecker
#
# Average Volume: $201,800.7
#
# ![arrow](./Tracker_files/arrow.png)![profile](./Tracker_files/wLaLSKSo_normal.jpg)
# ###### degenApe22
#
# Average Volume: $91,330.703
#
# ![arrow](./Tracker_files/arrow.png)![profile](./Tracker_files/qWU8wkXc_normal.jpg)
# ###### CryptoGodJohn
#
# Average Volume: $74,167.033
#
# ![arrow](./Tracker_files/arrow.png)Add Influencer
# #### Recent Calls
#
# See All![arrow](./Tracker_files/arrow.png)
#
# | S/N | Token | Date and Time (UTC) | Influencer | Buy Volume | Sell Volume | Call Market Cap |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1 | Benji Bananas$BENJI -0.00% | 09 Jan 2025 05:01:49 | Overdose_AIOverdose\_AI | $0 | $0 | $1.8m |
# | 2 | NEURALAI$NEURAL -0.00% | 09 Jan 2025 05:01:46 | Overdose_AIOverdose\_AI | $0 | $0 | $113.2m |
# | 3 | Mumu$MUMU +0.00% | 09 Jan 2025 05:01:46 | Overdose_AIOverdose\_AI | $0 | $0 | $2.8m |
# | 4 | GME (Ethereum)$GME +0.00% | 09 Jan 2025 05:01:46 | Overdose_AIOverdose\_AI | $0 | $0 | $108.2m |
# | 5 | Neiro on ETH$NEIRO -0.00% | 09 Jan 2025 05:01:46 | Overdose_AIOverdose\_AI | $0 | $0 | $41.7m |
# | 6 | KONDUX$KNDX -0.00% | 09 Jan 2025 05:01:46 | Overdose_AIOverdose\_AI | $0 | $0 | $50.4m |
#
# ###### Token
#
# ###### Influencer
#
# KONDUX $KNDX -0.00%![Overdose_AI](./Tracker_files/JRp4ttGe_normal.jpg)Overdose\_AI
#
# ---
#
# Neiro on ETH $NEIRO -0.00%![Overdose_AI](./Tracker_files/JRp4ttGe_normal.jpg)Overdose\_AI
#
# ---
#
# GME (Ethereum) $GME +0.00%![Overdose_AI](./Tracker_files/JRp4ttGe_normal.jpg)Overdose\_AI
#
# ---
#
# Mumu $MUMU +0.00%![Overdose_AI](./Tracker_files/JRp4ttGe_normal.jpg)Overdose\_AI
#
# ---
#
# NEURALAI $NEURAL -0.00%![Overdose_AI](./Tracker_files/JRp4ttGe_normal.jpg)Overdose\_AI
#
# ---
#
# Benji Bananas $BENJI -0.00%![Overdose_AI](./Tracker_files/JRp4ttGe_normal.jpg)Overdose\_AI
#
# ---
#
# #### Influencers Leaderboard
#
# All TimeLast 7 daysLast 30 daysLast 3 monthsAverage Buy VolumeHighest Buy VolumeAverage XsHighest XsAverage Follow up Call VolumeHighest Follow up Call VolumeNumber of Calls
#
# | S/N | Influencer | Average Buy Volume | Highest Buy volume | Average Xs | Highest Xs | Average Follow up Call Volume | Highest Follow up Call Volume | Number of Calls |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | X_Eye2023X\_Eye2023 | $11,929.293 | $70,189.1 MOODENG | 1.00x | 1.00x $DNA | $3,559.866 | $9,097.67 $CPAL | 8 |
# | 2 | IncomeSharksIncomeSharks | $455,035.262 | $2,744,110 ETH | 1.00x | 1.00x $BITCOIN | $3,446,579.893 | $2,370,250 $ETH | 8 |
# | 3 | GemsofRaGemsofRa | $15,406.12 | $50,928.2 AICM | 1.00x | 1.00x $XRP | $0 | $0 | 5 |
# | 4 | IcedKnifeIcedKnife | $28,922.46 | $77,019.3 FTM | 1.00x | 1.00x $JUP | $46,495.133 | $77,019.3 $FTM | 3 |
# | 5 | AltcoinMiyagiAltcoinMiyagi | $228,870.719 | $2,932,920 ETH | 1.00x | 1.00x $BTC | $318,556.431 | $2,762,070 $ETH | 18 |
# | 6 | gandalfcrypttogandalfcryptto | $248,414.958 | $1,490,010 ETH | 1.00x | 1.00x $ETH | $248,768.292 | $1,492,130 $ETH | 6 |
# | 7 | wPEPE_ERCwPEPE\_ERC | $20,232.664 | $86,327.3 MOODENG | 1.00x | 1.00x $MOODENG | $4,129.95 | $17,385.5 $CPAL | 7 |
# | 8 | MohsinAliSolngiMohsinAliSolngi | $228,940.962 | $973,550 BTC | 1.00x | 1.00x $USACOIN | $435,803.918 | $1,282,710 $BTC | 9 |
# | 9 | SaadKhan440SaadKhan440 | $0 | $0 | 1.00x | 1.00x $SHIFU | $0 | $0 | 2 |
# | 10 | Solemn_CapSolemn\_Cap | $8,536.496 | $27,652.4 CPAL | 1.00x | 1.00x $TRACK | $16,100.845 | $23,936.7 $CPAL | 5 |
# | 11 | CryptoKadunaCryptoKaduna | $289,546.235 | $1,137,620 ETH | 1.00x | 1.00x $TRUST | $0 | $0 | 4 |
# | 12 | CryptoGodJohnCryptoGodJohn | $758,298.96 | $2,226,470 BTC | 1.00x | 1.00x $BTC | $1,504,342.06 | $5,530,270 $ETH | 5 |
# | 13 | degenApe22degenApe22 | $116,012.284 | $815,407 ETH | 1.00x | 1.00x $ETH | $9,578,335.698 | $8,092,200 $ETH | 13 |
# | 14 | elonmuskelonmusk | $0 | $0 | 0x | 0x | $0 | $0 | N/A |
# | 15 | ZssBeckerZssBecker | $1,735,910 | $1,735,910 ETH | 1.00x | 1.00x $ETH | $0 | $0 | 1 |
# | 16 | CryptoWizarddCryptoWizardd | $46,566.574 | $348,553 ETH | 1.00x | 1.00x $WOO | $63,203.014 | $132,537 $NPC | 16 |
# | 17 | TrackerAI_ERCTrackerAI\_ERC | $149,945.417 | $788,130 ETH | 1.00x | 1.00x $ETH | $1,993,308.57 | $4,342,930 $ETH | 6 |
# | 18 | im_goombaim\_goomba | $251,366.601 | $1,932,990 ETH | 1.00x | 1.00x $DRAFT | $522,880.719 | $2,051,800 $BTC | 13 |
# | 19 | EricCryptomanEricCryptoman | $53,776.165 | $202,898 GATSBY | 1.00x | 1.00x $FUKU | $0 | $0 | 4 |
# | 20 | Overdose_AIOverdose\_AI | $10,394.635 | $49,678.1 AUTOS | 1.00x | 1.00x $AUTOS | $72,830.734 | $63,179.9 $GATSBY | 10 |
#
# ###### S/N
#
# ###### Influencer
#
# 1![X_Eye2023](./Tracker_files/iH5HwL_Y_normal.jpg)X\_Eye2023
#
# ---
#
# 2![IncomeSharks](./Tracker_files/_h2xv58V_normal.png)IncomeSharks
#
# ---
#
# 3![GemsofRa](./Tracker_files/1_rxr7uO_normal.jpg)GemsofRa
#
# ---
#
# 4![IcedKnife](./Tracker_files/OaAb9GI0_normal.jpg)IcedKnife
#
# ---
#
# 5![AltcoinMiyagi](./Tracker_files/Uo1GJxhw_normal.jpg)AltcoinMiyagi
#
# ---
#
# 6![gandalfcryptto](./Tracker_files/U9UUy9p4_normal.jpg)gandalfcryptto
#
# ---
#
# 7![wPEPE_ERC](./Tracker_files/Y-BW34Kf_normal.jpg)wPEPE\_ERC
#
# ---
#
# 8![MohsinAliSolngi](./Tracker_files/pXDooLTY_normal.jpg)MohsinAliSolngi
#
# ---
#
# 9![SaadKhan440](./Tracker_files/CiuxN-oB_normal.jpg)SaadKhan440
#
# ---
#
# 10![Solemn_Cap](./Tracker_files/VmUnXd8S_normal.jpg)Solemn\_Cap
#
# ---
#
# 11![CryptoKaduna](./Tracker_files/N6A-Up8e_normal.jpg)CryptoKaduna
#
# ---
#
# 12![CryptoGodJohn](./Tracker_files/qWU8wkXc_normal.jpg)CryptoGodJohn
#
# ---
#
# 13![degenApe22](./Tracker_files/wLaLSKSo_normal.jpg)degenApe22
#
# ---
#
# 14![elonmusk](./Tracker_files/kPL61o0F_normal.jpg)elonmusk
#
# ---
#
# 15![ZssBecker](./Tracker_files/S3-NhpCA_normal.jpg)ZssBecker
#
# ---
#
# 16![CryptoWizardd](./Tracker_files/WwOa201h_normal.jpg)CryptoWizardd
#
# ---
#
# 17![TrackerAI_ERC](./Tracker_files/JsxaZukm_normal.jpg)TrackerAI\_ERC
#
# ---
#
# 18![im_goomba](./Tracker_files/b2y4ycyn_normal.jpg)im\_goomba
#
# ---
#
# 19![EricCryptoman](./Tracker_files/XBGvOaoV_normal.jpg)EricCryptoman
#
# ---
#
# 20![Overdose_AI](./Tracker_files/JRp4ttGe_normal.jpg)Overdose\_AI
#
# ---
#
# #### All Tokens Stats
#
# VolumeMentions
#
# | S/N | Ticker | Highest volume | Top 3 Influencers | Number of mentions |
# | --- | --- | --- | --- | --- |
# | 1 | $ETH | $8,092,200 @degenApe22 | @AltcoinMiyagi@IncomeSharks@im\_goomba | 105 |
# | 2 | $BTC | $2,226,470 @CryptoGodJohn | @CryptoGodJohn@AltcoinMiyagi@MohsinAliSolngi | 36 |
# | 3 | $RAI | $653,463 @MohsinAliSolngi | @im\_goomba@MohsinAliSolngi | 6 |
# | 4 | $DSYNC | $352,248 @CryptoGodJohn | @CryptoGodJohn@TrackerAI\_ERC | 12 |
# | 5 | $GATSBY | $202,898 @EricCryptoman | @EricCryptoman@Overdose\_AI | 4 |
# | 6 | $INJ | $179,886 @CryptoWizardd | @CryptoWizardd | 8 |
# | 7 | $BITCOIN | $173,948 @IncomeSharks | @im\_goomba@IcedKnife@MohsinAliSolngi | 144 |
# | 8 | $NPC | $132,537 @CryptoWizardd | @CryptoWizardd | 4 |
# | 9 | $AUTOS | $126,424 @CryptoGodJohn | @CryptoGodJohn@Overdose\_AI | 2 |
# | 10 | $MOODENG | $86,327.3 @wPEPE\_ERC | @wPEPE\_ERC@X\_Eye2023 | 2 |
# | 11 | $FTM | $77,019.3 @IcedKnife | @IcedKnife | 3 |
# | 12 | $LAIKA | $76,858.3 @CryptoWizardd | @CryptoWizardd@X\_Eye2023@wPEPE\_ERC | 9 |
# | 13 | $CPAL | $73,226.2 @IncomeSharks | @IncomeSharks@wPEPE\_ERC@Solemn\_Cap | 19 |
# | 14 | $QF | $64,507.8 @AltcoinMiyagi | @AltcoinMiyagi | 9 |
# | 15 | $LNQ | $60,573 @CryptoWizardd | @CryptoWizardd | 1 |
# | 16 | $DEAI | $58,208.9 @CryptoWizardd | @CryptoWizardd@CryptoKaduna@Solemn\_Cap | 11 |
# | 17 | $GME | $57,765.7 @Overdose\_AI | @Overdose\_AI | 22 |
# | 18 | $SERV | $51,762.3 @degenApe22 | @degenApe22 | 7 |
# | 19 | $UNI | $50,960.4 @degenApe22 | @degenApe22 | 3 |
# | 20 | $AICM | $50,928.2 @GemsofRa | @GemsofRa | 1 |
# | 21 | $NEURAL | $46,156.2 @AltcoinMiyagi | @AltcoinMiyagi@TrackerAI\_ERC@Overdose\_AI | 26 |
# | 22 | $VERTAI | $43,510.8 @AltcoinMiyagi | @GemsofRa@AltcoinMiyagi | 9 |
# | 23 | $SPX | $38,087.3 @MohsinAliSolngi | @MohsinAliSolngi | 3 |
# | 24 | $XMW | $33,270.2 @degenApe22 | @GemsofRa@Overdose\_AI@degenApe22 | 13 |
# | 25 | $WOO | $30,776.6 @CryptoWizardd | @CryptoWizardd | 121 |
# | 26 | $PIN | $28,999.4 @CryptoGodJohn | @CryptoGodJohn@wPEPE\_ERC@TrackerAI\_ERC | 8 |
# | 27 | $ORBIT | $28,765.1 @im\_goomba | @im\_goomba | 3 |
# | 28 | $MAGA | $28,601.3 @Overdose\_AI | @Overdose\_AI | 22 |
# | 29 | $OMIRA | $24,522.8 @degenApe22 | @im\_goomba@degenApe22 | 5 |
# | 30 | $0XGAS | $21,591.5 @degenApe22 | @degenApe22 | 17 |
# | 31 | $OGPU | $15,896.3 @AltcoinMiyagi | @AltcoinMiyagi | 2 |
# | 32 | $ZIG | $12,802.5 @CryptoWizardd | @CryptoWizardd | 2 |
# | 33 | $MOG | $12,763.3 @wPEPE\_ERC | @wPEPE\_ERC | 1 |
# | 34 | $ORAI | $11,422.9 @IncomeSharks | @IncomeSharks | 8 |
# | 35 | $TAOBOT | $10,560.4 @CryptoWizardd | @CryptoWizardd | 1 |
# | 36 | $PAI | $9,984.78 @EricCryptoman | @EricCryptoman | 1 |
# | 37 | $EMP | $7,871.88 @CryptoWizardd | @CryptoWizardd | 1 |
# | 38 | $NEIRO | $7,827.21 @Overdose\_AI | @Overdose\_AI | 22 |
# | 39 | $DNA | $7,779.38 @AltcoinMiyagi | @AltcoinMiyagi@X\_Eye2023 | 3 |
# | 40 | $CPOOL | $7,119.29 @CryptoWizardd | @CryptoWizardd | 2 |
# | 41 | $BAZED | $6,900.41 @degenApe22 | @degenApe22 | 4 |
# | 42 | $TRACK | $6,428.17 @TrackerAI\_ERC | @TrackerAI\_ERC@X\_Eye2023@Solemn\_Cap | 45 |
# | 43 | $EAVE | $5,564.53 @AltcoinMiyagi | @AltcoinMiyagi | 1 |
# | 44 | $MUMU | $4,745.7 @Overdose\_AI | @Overdose\_AI | 22 |
# | 45 | $INFRA | $4,137.92 @AltcoinMiyagi | @AltcoinMiyagi | 13 |
# | 46 | $PEAS | $3,972.83 @degenApe22 | @degenApe22 | 9 |
# | 47 | $NAVI | $3,652.32 @AltcoinMiyagi | @AltcoinMiyagi | 3 |
# | 48 | $SOLANA | $3,579.94 @CryptoKaduna | @CryptoKaduna@X\_Eye2023@wPEPE\_ERC | 8 |
# | 49 | $AITAX | $3,269 @im\_goomba | @im\_goomba | 2 |
# | 50 | $KNDX | $2,878.53 @AltcoinMiyagi | @AltcoinMiyagi@Overdose\_AI | 32 |
# | 51 | $NFNT | $2,360.27 @AltcoinMiyagi | @AltcoinMiyagi | 1 |
# | 52 | $HASHAI | $2,221.88 @EricCryptoman | @EricCryptoman | 1 |
# | 53 | $SYNK | $1,393.15 @degenApe22 | @degenApe22 | 5 |
# | 54 | $CNET | $1,385.76 @AltcoinMiyagi | @AltcoinMiyagi | 1 |
# | 55 | $TWEET | $1,158.98 @im\_goomba | @im\_goomba | 3 |
# | 56 | $SIMAI | $731.805 @AltcoinMiyagi | @AltcoinMiyagi | 2 |
# | 57 | $WMC | $700.564 @CryptoWizardd | @CryptoWizardd | 1 |
# | 58 | $APES | $491.01 @im\_goomba | @im\_goomba | 2 |
# | 59 | $PONGO | $479.751 @gandalfcryptto | @gandalfcryptto | 2 |
# | 60 | $JEST | $418.277 @degenApe22 | @degenApe22 | 3 |
# | 61 | $DRAFT | $400.274 @im\_goomba | @im\_goomba | 1 |
# | 62 | $ZKAI | $310.372 @AltcoinMiyagi | @AltcoinMiyagi | 5 |
# | 63 | $HUSBY | $238.439 @AltcoinMiyagi | @AltcoinMiyagi | 1 |
# | 64 | $TSLA | $24.501 @im\_goomba | @im\_goomba@IncomeSharks | 3 |
# | 65 | $SHIFU | $0 @SaadKhan440 | @SaadKhan440 | 1 |
# | 66 | $USACOIN | $0 @MohsinAliSolngi | @MohsinAliSolngi | 1 |
# | 67 | $MYSTERY | $0 @MohsinAliSolngi | @MohsinAliSolngi | 1 |
# | 68 | $ENA | $0 @SaadKhan440 | @SaadKhan440 | 1 |
# | 69 | $JUP | $0 @IcedKnife | @IcedKnife | 2 |
# | 70 | $XRP | $0 @IncomeSharks | @IncomeSharks@gandalfcryptto@GemsofRa | 11 |
# | 71 | $CSWAP | $0 @degenApe22 | @degenApe22 | 3 |
# | 72 | $CHAT | $0 @AltcoinMiyagi | @AltcoinMiyagi | 3 |
# | 73 | $TRUST | $0 @CryptoKaduna | @CryptoKaduna | 1 |
# | 74 | $WLD | $0 @CryptoWizardd | @CryptoWizardd | 3 |
# | 75 | $GURU | $0 @GemsofRa | @GemsofRa | 1 |
# | 76 | $FUKU | $0 @EricCryptoman | @EricCryptoman | 1 |
# | 77 | $ETHEREUM | $0 @MohsinAliSolngi | @MohsinAliSolngi | 2 |
# | 78 | $ZEC | $0 @CryptoWizardd | @CryptoWizardd | 1 |
# | 79 | $EVOAI | $0 @im\_goomba | @im\_goomba | 3 |
# | 80 | $BENJI | $0 @Overdose\_AI | @Overdose\_AI | 22 |
# | 81 | $BIAI | $0 @gandalfcryptto | @gandalfcryptto | 1 |
# | 82 | $APE | $0 @CryptoWizardd | @CryptoWizardd | 1 |
# | 83 | $RSN | $0 @degenApe22 | @degenApe22 | 1 |
# | 84 | $ROUTE | $0 @CryptoWizardd | @CryptoWizardd | 1 |
# | 85 | $BUILD | $0 @AltcoinMiyagi | @AltcoinMiyagi | 1 |
# | 86 | $RDDT | $0 @IncomeSharks | @IncomeSharks | 9 |
# | 87 | $ECO | $0 @gandalfcryptto | @gandalfcryptto | 1 |
# | 88 | $ANDY | $0 @gandalfcryptto | @gandalfcryptto | 1 |
#
# ###### S/N
#
# ###### Ticker
#
# ###### Number Of Mentions
#
# 1$ETH105
#
# ---
#
# 2$BTC36
#
# ---
#
# 3$RAI6
#
# ---
#
# 4$DSYNC12
#
# ---
#
# 5$GATSBY4
#
# ---
#
# 6$INJ8
#
# ---
#
# 7$BITCOIN144
#
# ---
#
# 8$NPC4
#
# ---
#
# 9$AUTOS2
#
# ---
#
# 10$MOODENG2
#
# ---
#
# 11$FTM3
#
# ---
#
# 12$LAIKA9
#
# ---
#
# 13$CPAL19
#
# ---
#
# 14$QF9
#
# ---
#
# 15$LNQ1
#
# ---
#
# 16$DEAI11
#
# ---
#
# 17$GME22
#
# ---
#
# 18$SERV7
#
# ---
#
# 19$UNI3
#
# ---
#
# 20$AICM1
#
# ---
#
# 21$NEURAL26
#
# ---
#
# 22$VERTAI9
#
# ---
#
# 23$SPX3
#
# ---
#
# 24$XMW13
#
# ---
#
# 25$WOO121
#
# ---
#
# 26$PIN8
#
# ---
#
# 27$ORBIT3
#
# ---
#
# 28$MAGA22
#
# ---
#
# 29$OMIRA5
#
# ---
#
# 30$0XGAS17
#
# ---
#
# 31$OGPU2
#
# ---
#
# 32$ZIG2
#
# ---
#
# 33$MOG1
#
# ---
#
# 34$ORAI8
#
# ---
#
# 35$TAOBOT1
#
# ---
#
# 36$PAI1
#
# ---
#
# 37$EMP1
#
# ---
#
# 38$NEIRO22
#
# ---
#
# 39$DNA3
#
# ---
#
# 40$CPOOL2
#
# ---
#
# 41$BAZED4
#
# ---
#
# 42$TRACK45
#
# ---
#
# 43$EAVE1
#
# ---
#
# 44$MUMU22
#
# ---
#
# 45$INFRA13
#
# ---
#
# 46$PEAS9
#
# ---
#
# 47$NAVI3
#
# ---
#
# 48$SOLANA8
#
# ---
#
# 49$AITAX2
#
# ---
#
# 50$KNDX32
#
# ---
#
# 51$NFNT1
#
# ---
#
# 52$HASHAI1
#
# ---
#
# 53$SYNK5
#
# ---
#
# 54$CNET1
#
# ---
#
# 55$TWEET3
#
# ---
#
# 56$SIMAI2
#
# ---
#
# 57$WMC1
#
# ---
#
# 58$APES2
#
# ---
#
# 59$PONGO2
#
# ---
#
# 60$JEST3
#
# ---
#
# 61$DRAFT1
#
# ---
#
# 62$ZKAI5
#
# ---
#
# 63$HUSBY1
#
# ---
#
# 64$TSLA3
#
# ---
#
# 65$SHIFU1
#
# ---
#
# 66$USACOIN1
#
# ---
#
# 67$MYSTERY1
#
# ---
#
# 68$ENA1
#
# ---
#
# 69$JUP2
#
# ---
#
# 70$XRP11
#
# ---
#
# 71$CSWAP3
#
# ---
#
# 72$CHAT3
#
# ---
#
# 73$TRUST1
#
# ---
#
# 74$WLD3
#
# ---
#
# 75$GURU1
#
# ---
#
# 76$FUKU1
#
# ---
#
# 77$ETHEREUM2
#
# ---
#
# 78$ZEC1
#
# ---
#
# 79$EVOAI3
#
# ---
#
# 80$BENJI22
#
# ---
#
# 81$BIAI1
#
# ---
#
# 82$APE1
#
# ---
#
# 83$RSN1
#
# ---
#
# 84$ROUTE1
#
# ---
#
# 85$BUILD1
#
# ---
#
# 86$RDDT9
#
# ---
#
# 87$ECO1
#
# ---
#
# 88$ANDY1
#
# ---
#
# #### Platform Stats
#
# ![Number of users](./Tracker_files/stats1.png)
# ##### 6
#
# Number of users
#
# ![Tracked Influencers](./Tracker_files/stats2.png)
# ##### 20
#
# Tracked Influencers
#
# ![Purchased ad slot](./Tracker_files/stats3.png)
# ##### 0
#
# Purchased ad slot
#
# ![Daily visitors](./Tracker_files/stats4.png)
# ##### 11
#
# Daily visitors
#
# ![Weekly visitors](./Tracker_files/stats5.png)
# ##### 87
#
# Weekly visitors
#
# ![Monthly visitors](./Tracker_files/stats6.png)
# ##### 96
#
# Monthly visitors
#
# ![Daily visitors average](./Tracker_files/stats4.png)
# ##### 11
#
# Daily visitors average
#
# ![Weekly visitors average](./Tracker_files/stats5.png)
# ##### 12.4286
#
# Weekly visitors average
#
# ![Monthly visitors average](./Tracker_files/stats6.png)
# ##### 3.2000
#
# Monthly visitors average
#
# ![Premium users](./Tracker_files/stats7.png)
# ##### 0
#
# Premium users
#
# ![Premium+users](./Tracker_files/stats8.png)
# ##### 0
#
# Premium+users
#
# ![logo](./Tracker_files/logo.png)![twitter](./Tracker_files/twitter.png)![telegram](./Tracker_files/telegram.png)![footer-icon3](./Tracker_files/footer-icon3.png)![footer-icon4](./Tracker_files/footer-icon4.png)![footer-icon5](./Tracker_files/footer-icon5.png)

# %%
user_prompt = (
    f"Compare the job description and resume carefully and provide the ATS score (0-100)."
    f"\n\n### Job Description:\n"
    f"\n\n### Resume:\n"
)
user_prompt
# Out:
# 'Compare the job description and resume carefully and provide the ATS score (0-100).\n\n### Job Description:\n\n\n### Resume:\n'

# %%
import re
import requests
from markdownify import markdownify
from requests.exceptions import RequestException

def visit_webpage(url: str) -> str:
    """Visits a webpage at the given URL and returns its content as a markdown string.

    Args:
        url: The URL of the webpage to visit.

    Returns:
        The content of the webpage converted to Markdown, or an error message if the request fails.
    """
    try:
        # Send a GET request to the URL
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes

        # Convert the HTML content to Markdown
        markdown_content = markdownify(response.text).strip()

        # Remove multiple line breaks
        markdown_content = re.sub(r"\n{3,}", "\n\n", markdown_content)

        return markdown_content

    except RequestException as e:
        return f"Error fetching the webpage: {str(e)}"
    except Exception as e:
        return f"An unexpected error occurred: {str(e)}"

# %%
print(visit_webpage("https://dev-kol.trackerai.bot/"))
# Out:
# TrackerYou need to enable JavaScript to run this app.

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL for job search
url = 'https://dev-kol.trackerai.bot/'

# Send a GET request to fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find job postings
job_listings = soup.find_all()
print(job_listings)
# for job in job_listings:
#     title = job.find('h3').text.strip()
#     company = job.find('h4').text.strip()
#     description = job.find('p').text.strip()
#     print(f'Title: {title}, Company: {company}, Description: {description}')
# Out:
# [<html lang="en"><head><meta charset="utf-8"/><link href="/favicon.ico" rel="icon"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="#000000" name="theme-color"/><meta content="Web site created using create-react-app" name="description"/><link href="/logo192.png" rel="apple-touch-icon"/><link href="/manifest.json" rel="manifest"/><script src="https://unpkg.com/react/umd/react.development.js"></script><script src="https://unpkg.com/react-dom/umd/react-dom.development.js"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/styled-components/4.4.1/styled-components.min.js"></script><title>Tracker</title><script defer="defer" src="/static/js/main.38081f69.js"></script><link href="/static/css/main.fb6e0b22.css" rel="stylesheet"/></head><body><noscript>You need to enable JavaScript to run this app.</noscript><div id="root"></div></body></html>, <head><meta charset="utf-8"/><link href="/favicon.ico" rel="icon"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="#000000" name="theme-color"/><meta content="Web site created using create-react-app" name="description"/><link href="/logo192.png" rel="apple-touch-icon"/><link href="/manifest.json" rel="manifest"/><script src="https://unpkg.com/react/umd/react.development.js"></script><script src="https://unpkg.com/react-dom/umd/react-dom.development.js"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/styled-components/4.4.1/styled-components.min.js"></script><title>Tracker</title><script defer="defer" src="/static/js/main.38081f69.js"></script><link href="/static/css/main.fb6e0b22.css" rel="stylesheet"/></head>, <meta charset="utf-8"/>, <link href="/favicon.ico" rel="icon"/>, <meta content="width=device-width,initial-scale=1" name="viewport"/>, <meta content="#000000" name="theme-color"/>, <meta content="Web site created using create-react-app" name="description"/>, <link href="/logo192.png" rel="apple-touch-icon"/>, <link href="/manifest.json" rel="manifest"/>, <script src="https://unpkg.com/react/umd/react.development.js"></script>, <script src="https://unpkg.com/react-dom/umd/react-dom.development.js"></script>, <script src="https://cdnjs.cloudflare.com/ajax/libs/styled-components/4.4.1/styled-components.min.js"></script>, <title>Tracker</title>, <script defer="defer" src="/static/js/main.38081f69.js"></script>, <link href="/static/css/main.fb6e0b22.css" rel="stylesheet"/>, <body><noscript>You need to enable JavaScript to run this app.</noscript><div id="root"></div></body>, <noscript>You need to enable JavaScript to run this app.</noscript>, <div id="root"></div>]

# %%
from typing import List
from openai.types import Model
from rich.pretty import pprint
from pydantic import BaseModel, Field
from phi.agent import Agent, RunResponse
from phi.model.groq import Groq
from phi.tools.duckduckgo import DuckDuckGo


class MovieScript(BaseModel):
    setting: str = Field(..., description="Provide a nice setting for a blockbuster movie.")
    ending: str = Field(..., description="Ending of the movie. If not available, provide a happy ending.")
    genre: str = Field(
        ..., description="Genre of the movie. If not available, select action, thriller or romantic comedy."
    )
    name: str = Field(..., description="Give a name to this movie")
    characters: List[str] = Field(..., description="Name of characters for this movie.")
    storyline: str = Field(..., description="3 sentence storyline for the movie. Make it exciting!")

model = "llama-3.3-70b-versatile"
# Agent that uses JSON mode
json_mode_agent = Agent(
    model=Groq(id=model),
    description="You write movie scripts.",
    response_model=MovieScript,
)
# Agent that uses structured outputs
structured_output_agent = Agent(
    model=Groq(id=model),
    description="You write movie scripts in json format.",
    response_model=MovieScript,
    structured_outputs=True,
)


# Get the response in a variable
json_mode_response: RunResponse = json_mode_agent.run("New York")
pprint(json_mode_response.content)
# structured_output_response: RunResponse = structured_output_agent.run("New York")
# pprint(structured_output_response.content)

# json_mode_agent.print_response("New York")
# structured_output_agent.print_response("New York")
# Out:
# MovieScript(
# │   setting='New York City, with its vibrant streets and iconic landmarks',
# │   ending='The hero saves the day and gets the girl, with a dramatic finale at the Statue of Liberty',
# │   genre='Action',
# │   name='Big Apple Showdown',
# │   characters=['Jack Harris', 'Sarah Lee', 'Victor Vex'],
# │   storyline="When a powerful crime lord threatens to destroy the city, Jack Harris, a former detective, must join forces with Sarah Lee, a brilliant hacker, to take him down. As they navigate the city's underworld, they uncover a web of corruption and deceit that goes all the way to the top. With time running out, Jack and Sarah must use all their skills to stop the crime lord and save the city from destruction."
# )

# %%
from typing import List, Optional
import json

from pydantic import BaseModel
from groq import Groq

groq = Groq()

# Define a Pydantic model to enforce the structure of the output
class MovieScript(BaseModel):
    setting: str = Field(..., description="Provide a nice setting for a blockbuster movie.")
    ending: str = Field(..., description="Ending of the movie. If not available, provide a happy ending.")
    genre: str = Field(..., description="Genre of the movie. If not available, select action, thriller or romantic comedy.")
    name: str = Field(..., description="Give a name to this movie")
    characters: List[str] = Field(..., description="Name of characters for this movie.")
    storyline: str = Field(..., description="3 sentence storyline for the movie. Make it exciting!")


# Data model for LLM to generate
class Ingredient(BaseModel):
    name: str
    quantity: str
    quantity_unit: Optional[str]


class Recipe(BaseModel):
    recipe_name: str
    ingredients: List[Ingredient]
    directions: List[str]

class question(BaseModel):
    text: List[str] = Field(..., description="The list of the questions to ask the user for the job interview on given topic.")



def get_recipe(recipe_name: str) -> MovieScript:
    chat_completion = groq.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": f'''You write movie scripts with JSON output. Ensure the output strictly matches the schema with the fields:  
                'setting', 'ending', 'genre', 'name', 'characters', and 'storyline'. \n
                # Pass the json schema to the model. Pretty printing improves results.
                f" The JSON object must use the schema: {json.dumps(MovieScript.model_json_schema(), indent=2)}''',
            },
            {
                "role": "user",
                "content": f"create a script for {recipe_name}",
            },
        ],
        model="llama3-70b-8192",
        temperature=0,
        # Streaming is not supported in JSON mode
        stream=False,
        # Enable JSON mode by setting the response format
        response_format={"type": "json_object"},
    )
    return MovieScript.model_validate_json(chat_completion.choices[0].message.content)


def print_recipe(recipe: Recipe):
    print("Recipe:", recipe.recipe_name)

    print("\nIngredients:")
    for ingredient in recipe.ingredients:
        print(
            f"- {ingredient.name}: {ingredient.quantity} {ingredient.quantity_unit or ''}"
        )
    print("\nDirections:")
    for step, direction in enumerate(recipe.directions, start=1):
        print(f"{step}. {direction}")

def print_movie_script(script: MovieScript):
    print("Movie Script:")
    print(f"Name: {script.name}")
    print(f"Genre: {script.genre}")
    print(f"Setting: {script.setting}")
    print(f"Ending: {script.ending}")
    
    print("\nCharacters:")
    for character in script.characters:
        print(f"- {character}")
    
    print("\nStoryline:")
    print(f"{script.storyline}")

recipe = get_recipe("New York")
print_movie_script(recipe)
# Out:
# Movie Script:
# Name: Concrete Jungle
# Genre: Action
# Setting: New York City, present day
# Ending: The hero saves the city from destruction and finds love
#
# Characters:
# - Jack Harris, a former NYPD detective
# - Dr. Sophia Patel, a brilliant scientist
# - Victor Vex, a wealthy tech mogul
#
# Storyline:
# When a powerful technology falls into the wrong hands, Jack Harris must team up with Dr. Sophia Patel to stop Victor Vex from destroying New York City. As they race against time, they uncover a web of deceit and corruption that threatens the very fabric of the city. In the end, they must make a choice between saving the city or saving themselves.

# %%
from pydantic import BaseModel, Field
from typing import List, Literal, Optional


class InterviewQuestion(BaseModel):
    question: str = Field(..., description="The text of the interview question.")
    category: Literal["technical", "behavioral", "situational"] = Field(
        ..., description="The category of the question."
    )
    difficulty: Literal["beginner", "intermediate", "advanced"] = Field(
        ..., description="The difficulty level of the question."
    )
    tech_stack: Optional[List[str]] = Field(
        None,
        description="The list of technologies or skills the question is related to.",
    )
    experience_level: Literal["entry-level", "mid-level", "senior"] = Field(
        ..., description="The required experience level for this question."
    )


class JobInterviewQuestions(BaseModel):
    role: str = Field(..., description="The job role for which questions are prepared.")
    tech_stack: List[str] = Field(
        ..., description="The technologies and tools required for the job role."
    )
    experience_level: Literal["entry-level", "mid-level", "senior"] = Field(
        ..., description="The experience level for the candidate."
    )
    questions: List[InterviewQuestion] = Field(
        ..., description="A list of interview questions tailored for the role."
    )


# Example Usage
example_data = {
    "role": "Software Engineer",
    "tech_stack": ["Python", "Django", "AWS"],
    "experience_level": "mid-level",
    "questions": [
        {
            "question": "Explain the difference between synchronous and asynchronous programming in Python.",
            "category": "technical",
            "difficulty": "intermediate",
            "tech_stack": ["Python"],
            "experience_level": "mid-level",
        },
        {
            "question": "Describe a time when you had to resolve a conflict in a team.",
            "category": "behavioral",
            "difficulty": "intermediate",
            "tech_stack": [],
            "experience_level": "mid-level",
        },
    ],
}

content = """ Act as a professional job interview assistant. Retrieve all relevant interview questions from the web for the specified job role. Tailor the questions based on:

The required experience level of the candidate in the field (e.g., entry-level, mid-level, senior).
The technical skills and tech stacks mentioned in the job description.
General and behavioral competencies typically expected for the role.
Ensure the questions cover a mix of technical expertise, problem-solving skills, and situational scenarios that are aligned with the responsibilities of the role. Provide a comprehensive list of questions categorized by type (technical, behavioral, situational) and difficulty level (beginner, intermediate, advanced) """

jd = """ Job Overview

With AI / ML gaining stronghold in improving human lives, we have opportunities wherein good AI/ML experienced engineers can contribute to building a more improved life experience.
Looking for ambitious, achievement-oriented technocrats with strong work experience in AI/ML related tools & technologies.


Experience:

3 – 8 years of experience in AI/ML technologies more focused on image processing


Skills & Competencies:

Python, PyTorch
TensorFlow
Deep Learning
AI/ML


Required Skills & Qualifications:

B.Tech/B.E/M.Tech/M.E in Computer Science stream preferred.
Strong proficiency in TensorFlow, PyTorch, and Python
Deep understanding of GPU, CPU and AI Accelerator architectures, with hands-on experience in performance tuning for ML workloads.
Experience / Exposure to AI based solutions for Cameras/OpenCV in Android Environment.
Ability to work in a fast-paced, collaborative environment, with excellent communication and teamwork skills.
Strong understanding of Deep Learning """

def get_recipe(jd: str, content:str) -> JobInterviewQuestions:
    chat_completion = groq.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": f'''{content}. \n
                # Pass the json schema to the model. Pretty printing improves results.
                f" The JSON object must use the schema: {json.dumps(JobInterviewQuestions.model_json_schema(), indent=2)}''',
            },
            {
                "role": "user",
                "content": f"create a list of questions for below job description:\n {jd}",
            },
        ],
        model="llama3-70b-8192",
        temperature=0,
        # Streaming is not supported in JSON mode
        stream=False,
        # Enable JSON mode by setting the response format
        response_format={"type": "json_object"},
    )
    return JobInterviewQuestions.model_validate_json(chat_completion.choices[0].message.content)


response_jd = get_recipe(jd, content)

# %%
import json

def print_job_questions_json(job_questions):
    print(json.dumps(job_questions.model_dump(), indent=4))
print_job_questions_json(response_jd)
# Out:
# {
#     "role": "AI/ML Engineer",
#     "tech_stack": [
#         "Python",
#         "PyTorch",
#         "TensorFlow",
#         "Deep Learning",
#         "AI/ML",
#         "GPU",
#         "CPU",
#         "AI Accelerator",
#         "OpenCV",
#         "Android"
#     ],
#     "experience_level": "mid-level",
#     "questions": [
#         {
#             "question": "What is your experience with deep learning frameworks like PyTorch and TensorFlow?",
#             "category": "technical",
#             "difficulty": "intermediate",
#             "tech_stack": [
#                 "PyTorch",
#                 "TensorFlow"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "How do you optimize the performance of a machine learning model for deployment on a GPU?",
#             "category": "technical",
#             "difficulty": "advanced",
#             "tech_stack": [
#                 "GPU"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "Can you explain the concept of transfer learning in deep learning?",
#             "category": "technical",
#             "difficulty": "beginner",
#             "tech_stack": [
#                 "Deep Learning"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "How do you handle overfitting in a deep learning model?",
#             "category": "technical",
#             "difficulty": "intermediate",
#             "tech_stack": [
#                 "Deep Learning"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "What is your experience with OpenCV and how have you used it in AI-based solutions for cameras?",
#             "category": "technical",
#             "difficulty": "intermediate",
#             "tech_stack": [
#                 "OpenCV"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "Can you describe a project you worked on that involved image processing using AI/ML?",
#             "category": "behavioral",
#             "difficulty": "intermediate",
#             "tech_stack": [
#                 "AI/ML",
#                 "Image Processing"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "How do you stay updated with the latest developments in AI/ML and deep learning?",
#             "category": "behavioral",
#             "difficulty": "beginner",
#             "tech_stack": [
#                 "AI/ML",
#                 "Deep Learning"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "Can you walk me through a time when you had to troubleshoot a performance issue in a machine learning model?",
#             "category": "situational",
#             "difficulty": "intermediate",
#             "tech_stack": [
#                 "Machine Learning"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "How do you collaborate with cross-functional teams to develop AI-based solutions?",
#             "category": "behavioral",
#             "difficulty": "intermediate",
#             "tech_stack": [
#                 "AI/ML"
#             ],
#             "experience_level": "mid-level"
#         },
#         {
#             "question": "Can you explain the concept of batch normalization in deep neural networks?",
#             "category": "technical",
#             "difficulty": "advanced",
#             "tech_stack": [
#                 "Deep Learning"
#             ],
#             "experience_level": "mid-level"
#         }
#     ]
# }

# %%
from phi.model.groq import Groq

model = "llama-3.3-70b-versatile"
# Agent that uses JSON mode
json_mode_agent = Agent(
    model=Groq(id=model),
    tools=[DuckDuckGo()],
    description=f"{content}",
    # show_tool_calls=True,
    # markdown=True,
    # debug=True,
    # response_model=JobInterviewQuestions,
)
json_mode_response: RunResponse = json_mode_agent.run(f"create a list of questions from the web search tool for below job description:\n {jd}")
pprint(json_mode_response.content)
# Out:
# WARNING  Could not run function duckduckgo_search(query=TensorFlow PyTorch interview questions, max_results=10)
# ERROR    _text_extract_json() keywords='TensorFlow PyTorch interview questions' ValueError: subsection not found
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          63, in _text_extract_json
#              end = html_bytes.index(b");DDG.duckbar.load(", start)
#          ValueError: subsection not found
#
#          The above exception was the direct cause of the following exception:
#
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 307, in _text_api_page
#              page_data = _text_extract_json(resp_content, keywords)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          68, in _text_extract_json
#              raise DuckDuckGoSearchException(f"_text_extract_json() {keywords=} {type(ex).__name__}: {ex}") from ex
#          duckduckgo_search.exceptions.DuckDuckGoSearchException: _text_extract_json() keywords='TensorFlow PyTorch
#          interview questions' ValueError: subsection not found
# WARNING  Could not run function duckduckgo_search(query=Deep Learning interview questions, max_results=10)
# ERROR    _text_extract_json() keywords='Deep Learning interview questions' ValueError: subsection not found
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          63, in _text_extract_json
#              end = html_bytes.index(b");DDG.duckbar.load(", start)
#          ValueError: subsection not found
#
#          The above exception was the direct cause of the following exception:
#
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 307, in _text_api_page
#              page_data = _text_extract_json(resp_content, keywords)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          68, in _text_extract_json
#              raise DuckDuckGoSearchException(f"_text_extract_json() {keywords=} {type(ex).__name__}: {ex}") from ex
#          duckduckgo_search.exceptions.DuckDuckGoSearchException: _text_extract_json() keywords='Deep Learning
#          interview questions' ValueError: subsection not found
# WARNING  Could not run function duckduckgo_search(query=AI/ML interview questions for 3-8 years of experience,
#          max_results=10)
# ERROR    _text_extract_json() keywords='AI/ML interview questions for 3-8 years of experience' ValueError:
#          subsection not found
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          63, in _text_extract_json
#              end = html_bytes.index(b");DDG.duckbar.load(", start)
#          ValueError: subsection not found
#
#          The above exception was the direct cause of the following exception:
#
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 307, in _text_api_page
#              page_data = _text_extract_json(resp_content, keywords)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          68, in _text_extract_json
#              raise DuckDuckGoSearchException(f"_text_extract_json() {keywords=} {type(ex).__name__}: {ex}") from ex
#          duckduckgo_search.exceptions.DuckDuckGoSearchException: _text_extract_json() keywords='AI/ML interview
#          questions for 3-8 years of experience' ValueError: subsection not found
# WARNING  Could not run function duckduckgo_search(query=situational interview questions for AI/ML engineers,
#          max_results=10)
# ERROR    _text_extract_json() keywords='situational interview questions for AI/ML engineers' ValueError: subsection
#          not found
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          63, in _text_extract_json
#              end = html_bytes.index(b");DDG.duckbar.load(", start)
#          ValueError: subsection not found
#
#          The above exception was the direct cause of the following exception:
#
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 307, in _text_api_page
#              page_data = _text_extract_json(resp_content, keywords)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/utils.py", line
#          68, in _text_extract_json
#              raise DuckDuckGoSearchException(f"_text_extract_json() {keywords=} {type(ex).__name__}: {ex}") from ex
#          duckduckgo_search.exceptions.DuckDuckGoSearchException: _text_extract_json() keywords='situational
#          interview questions for AI/ML engineers' ValueError: subsection not found
# WARNING  Could not run function duckduckgo_search(query=GPU CPU AI Accelerator architectures interview questions,
#          max_results=10)
# ERROR    https://links.duckduckgo.com/d.js?q=GPU+CPU+AI+Accelerator+architectures+interview+questions&kl=wt-wt&l=wt
#          -wt&p=&s=0&df=&vqd=4-151385257159398521233133876581782636869&bing_market=wt-WT&ex=-1 202 Ratelimit
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 306, in _text_api_page
#              resp_content = self._get_url("GET", "https://links.duckduckgo.com/d.js", params=payload)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 134, in _get_url
#              raise RatelimitException(f"{resp.url} {resp.status_code} Ratelimit")
#          duckduckgo_search.exceptions.RatelimitException:
#          https://links.duckduckgo.com/d.js?q=GPU+CPU+AI+Accelerator+architectures+interview+questions&kl=wt-wt&l=wt
#          -wt&p=&s=0&df=&vqd=4-151385257159398521233133876581782636869&bing_market=wt-WT&ex=-1 202 Ratelimit
# WARNING  Could not run function duckduckgo_search(query=AI based solutions for Cameras/OpenCV in Android
#          Environment interview questions, max_results=10)
# ERROR    https://links.duckduckgo.com/d.js?q=AI+based+solutions+for+Cameras%2FOpenCV+in+Android+Environment+intervi
#          ew+questions&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-245317666238434333142890071621918944044&bing_market=wt-WT&e
#          x=-1 202 Ratelimit
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 306, in _text_api_page
#              resp_content = self._get_url("GET", "https://links.duckduckgo.com/d.js", params=payload)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 134, in _get_url
#              raise RatelimitException(f"{resp.url} {resp.status_code} Ratelimit")
#          duckduckgo_search.exceptions.RatelimitException:
#          https://links.duckduckgo.com/d.js?q=AI+based+solutions+for+Cameras%2FOpenCV+in+Android+Environment+intervi
#          ew+questions&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-245317666238434333142890071621918944044&bing_market=wt-WT&e
#          x=-1 202 Ratelimit
# WARNING  Could not run function duckduckgo_search(query=collaborative environment interview questions for AI/ML
#          engineers, max_results=10)
# ERROR    https://links.duckduckgo.com/d.js?q=collaborative+environment+interview+questions+for+AI%2FML+engineers&kl
#          =wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-17229064698084896285378141587894182331&bing_market=wt-WT&ex=-1 202
#          Ratelimit
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 306, in _text_api_page
#              resp_content = self._get_url("GET", "https://links.duckduckgo.com/d.js", params=payload)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 134, in _get_url
#              raise RatelimitException(f"{resp.url} {resp.status_code} Ratelimit")
#          duckduckgo_search.exceptions.RatelimitException:
#          https://links.duckduckgo.com/d.js?q=collaborative+environment+interview+questions+for+AI%2FML+engineers&kl
#          =wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-17229064698084896285378141587894182331&bing_market=wt-WT&ex=-1 202
#          Ratelimit
# WARNING  Could not run function duckduckgo_search(query=communication and teamwork skills interview questions for
#          AI/ML engineers, max_results=10)
# ERROR    https://links.duckduckgo.com/d.js?q=communication+and+teamwork+skills+interview+questions+for+AI%2FML+engi
#          neers&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-227123695564880734948269020122662607783&bing_market=wt-WT&ex=-1
#          202 Ratelimit
#          Traceback (most recent call last):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/function.py", line 372,
#          in execute
#              self.result = self.function.entrypoint(**entrypoint_args, **self.arguments)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 38, in wrapper_function
#              return wrapper(*args, **kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py",
#          line 111, in __call__
#              res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/phi/tools/duckduckgo.py", line 69,
#          in duckduckgo_search
#              return json.dumps(ddgs.text(keywords=query, max_results=(self.fixed_max_results or max_results)),
#          indent=2)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 244, in text
#              results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 331, in _text_api
#              raise e
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 328, in _text_api
#              for r in self._executor.map(_text_api_page, slist):
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 621, in
#          result_iterator
#              yield _result_or_cancel(fs.pop())
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 319, in
#          _result_or_cancel
#              return fut.result(timeout)
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 458, in
#          result
#              return self.__get_result()
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/_base.py", line 403, in
#          __get_result
#              raise self._exception
#            File "/home/dnk131/miniconda3/envs/snode/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#              result = self.fn(*self.args, **self.kwargs)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 306, in _text_api_page
#              resp_content = self._get_url("GET", "https://links.duckduckgo.com/d.js", params=payload)
#            File
#          "/home/dnk131/miniconda3/envs/snode/lib/python3.10/site-packages/duckduckgo_search/duckduckgo_search.py",
#          line 134, in _get_url
#              raise RatelimitException(f"{resp.url} {resp.status_code} Ratelimit")
#          duckduckgo_search.exceptions.RatelimitException:
#          https://links.duckduckgo.com/d.js?q=communication+and+teamwork+skills+interview+questions+for+AI%2FML+engi
#          neers&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-227123695564880734948269020122662607783&bing_market=wt-WT&ex=-1
#          202 Ratelimit
# "Based on the job description, here are some potential interview questions that may be asked:\n\n**Technical Questions**\n\n1. What is your experience with AI/ML technologies, particularly in image processing?\n2. How do you stay up-to-date with the latest developments in AI/ML?\n3. Can you explain the concept of convolutional neural networks (CNNs) and their application in image processing?\n4. How do you optimize the performance of AI/ML models, particularly in terms of GPU and CPU utilization?\n5. Can you describe your experience with TensorFlow and PyTorch, and how you have used them in previous projects?\n\n**Behavioral Questions**\n\n1. Can you describe a situation where you had to work collaboratively with a team to develop an AI/ML solution?\n2. How do you handle conflicts or disagreements within a team, particularly when working on a complex AI/ML project?\n3. Can you tell me about a time when you had to communicate complex technical concepts to a non-technical audience?\n4. How do you prioritize your work and manage your time when working on a project with multiple deadlines and competing demands?\n5. Can you describe your experience with agile development methodologies and how you have applied them in previous projects?\n\n**Situational Questions**\n\n1. Suppose you are working on a project to develop an AI-powered image classification system, and you encounter a problem with the model's accuracy. How would you troubleshoot the issue and improve the model's performance?\n2. Imagine you are working in a team to develop an AI-powered chatbot, and one of your team members is not pulling their weight. How would you handle the situation and ensure the project is completed on time?\n3. Can you describe a situation where you had to adapt to a changing project scope or requirements, particularly in an AI/ML project?\n4. Suppose you are working on a project to develop an AI-powered predictive maintenance system, and you encounter a problem with the data quality. How would you handle the issue and ensure the model is trained on high-quality data?\n5. Can you describe a situation where you had to communicate the results of an AI/ML project to a stakeholder, and how you ensured that the stakeholder understood the results and their implications?\n\n**GPU, CPU, and AI Accelerator Architectures Questions**\n\n1. Can you describe the differences between GPU and CPU architectures, and how they are used in AI/ML computing?\n2. How do you optimize the performance of AI/ML models on GPU and CPU architectures?\n3. Can you explain the concept of AI accelerators, such as TPUs and GPUs, and how they are used in AI/ML computing?\n4. How do you ensure that your AI/ML models are optimized for deployment on different hardware platforms, including GPUs, CPUs, and AI accelerators?\n5. Can you describe your experience with hardware acceleration techniques, such as parallel processing and distributed computing, and how you have applied them in previous projects?\n\n**AI-based Solutions for Cameras/OpenCV in Android Environment Questions**\n\n1. Can you describe your experience with OpenCV and its application in computer vision tasks?\n2. How do you develop AI-powered camera applications, such as object detection and image classification, using OpenCV and Android?\n3. Can you explain the concept of camera calibration and how it is used in computer vision tasks?\n4. How do you optimize the performance of AI-powered camera applications on Android devices, particularly in terms of power consumption and latency?\n5. Can you describe your experience with Android development and how you have integrated AI/ML models into Android applications?\n\n**Collaborative Environment Questions**\n\n1. Can you describe your experience working in a collaborative environment, particularly in an AI/ML team?\n2. How do you ensure that you are communicating effectively with your team members, particularly in a remote or distributed team?\n3. Can you tell me about a time w ...

# %%
print(json_mode_response.content)
# Out:
# Based on the job description, here are some potential interview questions that may be asked:
#
# **Technical Questions**
#
# 1. What is your experience with AI/ML technologies, particularly in image processing?
# 2. How do you stay up-to-date with the latest developments in AI/ML?
# 3. Can you explain the concept of convolutional neural networks (CNNs) and their application in image processing?
# 4. How do you optimize the performance of AI/ML models, particularly in terms of GPU and CPU utilization?
# 5. Can you describe your experience with TensorFlow and PyTorch, and how you have used them in previous projects?
#
# **Behavioral Questions**
#
# 1. Can you describe a situation where you had to work collaboratively with a team to develop an AI/ML solution?
# 2. How do you handle conflicts or disagreements within a team, particularly when working on a complex AI/ML project?
# 3. Can you tell me about a time when you had to communicate complex technical concepts to a non-technical audience?
# 4. How do you prioritize your work and manage your time when working on a project with multiple deadlines and competing demands?
# 5. Can you describe your experience with agile development methodologies and how you have applied them in previous projects?
#
# **Situational Questions**
#
# 1. Suppose you are working on a project to develop an AI-powered image classification system, and you encounter a problem with the model's accuracy. How would you troubleshoot the issue and improve the model's performance?
# 2. Imagine you are working in a team to develop an AI-powered chatbot, and one of your team members is not pulling their weight. How would you handle the situation and ensure the project is completed on time?
# 3. Can you describe a situation where you had to adapt to a changing project scope or requirements, particularly in an AI/ML project?
# 4. Suppose you are working on a project to develop an AI-powered predictive maintenance system, and you encounter a problem with the data quality. How would you handle the issue and ensure the model is trained on high-quality data?
# 5. Can you describe a situation where you had to communicate the results of an AI/ML project to a stakeholder, and how you ensured that the stakeholder understood the results and their implications?
#
# **GPU, CPU, and AI Accelerator Architectures Questions**
#
# 1. Can you describe the differences between GPU and CPU architectures, and how they are used in AI/ML computing?
# 2. How do you optimize the performance of AI/ML models on GPU and CPU architectures?
# 3. Can you explain the concept of AI accelerators, such as TPUs and GPUs, and how they are used in AI/ML computing?
# 4. How do you ensure that your AI/ML models are optimized for deployment on different hardware platforms, including GPUs, CPUs, and AI accelerators?
# 5. Can you describe your experience with hardware acceleration techniques, such as parallel processing and distributed computing, and how you have applied them in previous projects?
#
# **AI-based Solutions for Cameras/OpenCV in Android Environment Questions**
#
# 1. Can you describe your experience with OpenCV and its application in computer vision tasks?
# 2. How do you develop AI-powered camera applications, such as object detection and image classification, using OpenCV and Android?
# 3. Can you explain the concept of camera calibration and how it is used in computer vision tasks?
# 4. How do you optimize the performance of AI-powered camera applications on Android devices, particularly in terms of power consumption and latency?
# 5. Can you describe your experience with Android development and how you have integrated AI/ML models into Android applications?
#
# **Collaborative Environment Questions**
#
# 1. Can you describe your experience working in a collaborative environment, particularly in an AI/ML team?
# 2. How do you ensure that you are communicating effectively with your team members, particularly in a remote or distributed team?
# 3. Can you tell me about a time when you had to work with a cross-functional team, including data scientists, engineers, and product managers, to develop an AI/ML solution?
# 4. How do you handle conflicts or disagreements within a team, particularly when working on a complex AI/ML project?
# 5. Can you describe your experience with agile development methodologies and how you have applied them in previous projects to ensure collaboration and teamwork?
#
# **Communication and Teamwork Skills Questions**
#
# 1. Can you describe your experience with communication and teamwork, particularly in an AI/ML team?
# 2. How do you ensure that you are communicating effectively with your team members, particularly in a remote or distributed team?
# 3. Can you tell me about a time when you had to communicate complex technical concepts to a non-technical audience?
# 4. How do you handle conflicts or disagreements within a team, particularly when working on a complex AI/ML project?
# 5. Can you describe your experience with agile development methodologies and how you have applied them in previous projects to ensure collaboration and teamwork?
#
# Note that these questions are not exhaustive, and you may be asked other questions that are specific to the company, role, or industry. It's also important to be prepared to ask questions during the interview, such as about the company culture, team dynamics, or opportunities for growth and development.

# %%
model = "llama-3.3-70b-versatile"
# Agent that uses JSON mode
pydantic_agent = Agent(
    model=Groq(id=model),
    response_model=JobInterviewQuestions,
)
response: RunResponse = pydantic_agent.run(f"just list out the questions in the response model format from the given text:\n{json_mode_response.content}")
pprint(response.content)
# Out:
# JobInterviewQuestions(
# │   role='AI/ML Engineer',
# │   tech_stack=['AI/ML', 'TensorFlow', 'PyTorch', 'OpenCV', 'GPU', 'CPU', 'Android'],
# │   experience_level='mid-level',
# │   questions=[
# │   │   InterviewQuestion(
# │   │   │   question='What is your experience with AI/ML technologies, particularly in image processing?',
# │   │   │   category='technical',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=['AI/ML'],
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you stay up-to-date with the latest developments in AI/ML?',
# │   │   │   category='technical',
# │   │   │   difficulty='beginner',
# │   │   │   tech_stack=['AI/ML'],
# │   │   │   experience_level='entry-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you explain the concept of convolutional neural networks (CNNs) and their application in image processing?',
# │   │   │   category='technical',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=['CNNs'],
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you optimize the performance of AI/ML models, particularly in terms of GPU and CPU utilization?',
# │   │   │   category='technical',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['GPU', 'CPU'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with TensorFlow and PyTorch, and how you have used them in previous projects?',
# │   │   │   category='technical',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=['TensorFlow', 'PyTorch'],
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe a situation where you had to work collaboratively with a team to develop an AI/ML solution?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you handle conflicts or disagreements within a team, particularly when working on a complex AI/ML project?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you tell me about a time when you had to communicate complex technical concepts to a non-technical audience?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you prioritize your work and manage your time when working on a project with multiple deadlines and competing demands?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with agile development methodologies and how you have applied them in previous projects?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question="Suppose you are working on a project to develop an AI-powered image classification system, and you encounter a problem with the model's accuracy. How would you troubleshoot the issue and improve the model's performance?",
# │   │   │   category='situational',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['AI/ML'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Imagine you are working in a team to develop an AI-powered chatbot, and one of your team members is not pulling their weight. How would you handle the situation and ensure the project is completed on time?',
# │   │   │   category='situational',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe a situation where you had to adapt to a changing project scope or requirements, particularly in an AI/ML project?',
# │   │   │   category='situational',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Suppose you are working on a project to develop an AI-powered predictive maintenance system, and you encounter a problem with the data quality. How would you handle the issue and ensure the model is trained on high-quality data?',
# │   │   │   category='situational',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['AI/ML'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe a situation where you had to communicate the results of an AI/ML project to a stakeholder, and how you ensured that the stakeholder understood the results and their implications?',
# │   │   │   category='situational',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe the differences between GPU and CPU architectures, and how they are used in AI/ML computing?',
# │   │   │   category='technical',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=['GPU', 'CPU'],
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you optimize the performance of AI/ML models on GPU and CPU architectures?',
# │   │   │   category='technical',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['GPU', 'CPU'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you explain the concept of AI accelerators, such as TPUs and GPUs, and how they are used in AI/ML computing?',
# │   │   │   category='technical',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=['TPUs', 'GPUs'],
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you ensure that your AI/ML models are optimized for deployment on different hardware platforms, including GPUs, CPUs, and AI accelerators?',
# │   │   │   category='technical',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['GPUs', 'CPUs', 'AI accelerators'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with hardware acceleration techniques, such as parallel processing and distributed computing, and how you have applied them in previous projects?',
# │   │   │   category='technical',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['parallel processing', 'distributed computing'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with OpenCV and its application in computer vision tasks?',
# │   │   │   category='technical',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=['OpenCV'],
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you develop AI-powered camera applications, such as object detection and image classification, using OpenCV and Android?',
# │   │   │   category='technical',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['OpenCV', 'Android'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you explain the concept of camera calibration and how it is used in computer vision tasks?',
# │   │   │   category='technical',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=['camera calibration'],
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you optimize the performance of AI-powered camera applications on Android devices, particularly in terms of power consumption and latency?',
# │   │   │   category='technical',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['Android'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with Android development and how you have integrated AI/ML models into Android applications?',
# │   │   │   category='technical',
# │   │   │   difficulty='advanced',
# │   │   │   tech_stack=['Android'],
# │   │   │   experience_level='senior'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience working in a collaborative environment, particularly in an AI/ML team?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you ensure that you are communicating effectively with your team members, particularly in a remote or distributed team?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you tell me about a time when you had to work with a cross-functional team, including data scientists, engineers, and product managers, to develop an AI/ML solution?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you handle conflicts or disagreements within a team, particularly when working on a complex AI/ML project?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with agile development methodologies and how you have applied them in previous projects to ensure collaboration and teamwork?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with communication and teamwork, particularly in an AI/ML team?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you ensure that you are communicating effectively with your team members, particularly in a remote or distributed team?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you tell me about a time when you had to communicate complex technical concepts to a non-technical audience?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='How do you handle conflicts or disagreements within a team, particularly when working on a complex AI/ML project?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   ),
# │   │   InterviewQuestion(
# │   │   │   question='Can you describe your experience with agile development methodologies and how you have applied them in previous projects to ensure collaboration and teamwork?',
# │   │   │   category='behavioral',
# │   │   │   difficulty='intermediate',
# │   │   │   tech_stack=None,
# │   │   │   experience_level='mid-level'
# │   │   )
# │   ]
# )

# %%
len(response.content.questions)
# Out:
# 35
